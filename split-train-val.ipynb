# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Tue Sep 10 21:59:37 2019
split train and val
@author: debjani
python split_train_val.py
"""
import numpy as np
import shutil
import glob
import os
from pathlib import Path

########################################################################

original_dataset_dir= "data_HR/data/images" 
get_files_path = original_dataset_dir + "/*.npy"
fpath_list = sorted(glob.glob(get_files_path))

#original_dataset_dir = "/Users/debjani/Desktop/Mila_intern/SEGMENTATION/data/dataset/hr_image/data/images/"
#get_files_path = original_dataset_dir + "/*.npy"
#original_dataset_dir + "/*.npy"

# make the directories
base_dir = "data_HR" 
#base_dir = "/Users/debjani/Desktop/Mila_intern/SEGMENTATION/data/dataset/hr_image/"
train_dir = os.path.join(base_dir, 'train','images')
if not os.path.exists(train_dir):
        os.mkdir(train_dir)
    
validation_dir = os.path.join(base_dir, 'val','images')
if not os.path.exists(validation_dir):
        os.mkdir(validation_dir)
        
        
###############################################################################
validation_split = 0.2
dataset_size = len(fpath_list)
indices = list(range(dataset_size))
split = int(np.floor(validation_split * dataset_size))
if 1 :
    np.random.seed(1337)
    np.random.shuffle(indices)
train_indices, valid_indices = indices[split:], indices[:split]
print(len(train_indices), len(valid_indices))
############################################################

for i in train_indices:
    fname = fpath_list[i]
    fname = fname.split("/")
    fname = (fname[-1])
    src = os.path.join(original_dataset_dir, fname)
    dst = os.path.join(train_dir, fname)
    shutil.copyfile(src, dst)


for i in valid_indices:
    fname = fpath_list[i]
    fname = fname.split("/")
    fname = (fname[-1])
    src = os.path.join(original_dataset_dir, fname)
    dst = os.path.join(validation_dir, fname)
    shutil.copyfile(src, dst)
# Out:
# 733 183

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sun Aug 25 18:17:43 2019
Script: This is for making the validation mask data
"""

# ----------------Importing required packages---------------------------
import shutil
import glob
import os
# ----------------transferring masks corrsponding to correct image-------------
#original_dataset_dir = "../data/dataset/train/images/"
#label_dir  = "../data/dataset/train/masks/"
#
## copying files to their correspondig folder----------------------------------
#path = "../data/dataset/train/"
#folder = input("give the folder name")
#data_dir = os.path.join(path,folder)
#if not os.path.exists(data_dir):
#    os.mkdir(data_dir)
## Getting names of all files in the folder------------------------------------
#get_files_path = original_dataset_dir + "/*.*"
#fpath_list = sorted(glob.glob(get_files_path))
#for file in fpath_list:
#    #print(file)
#    fname = str(file[29:-4] + "_a" + ".npy")
#    src = os.path.join(label_dir, fname)
#    dst = os.path.join(data_dir, fname)
#    shutil.copyfile(src, dst)
#----------------making mask folder for validation data------------------------
#original_dataset_dir = "data_HR/train/images"
original_dataset_dir = "data_HR/val/images"


print(original_dataset_dir)
label_dir  = "data_HR/data/masks"
#data_dir  = "data_HR/train/masks"
data_dir  = "data_HR/val/masks"


# copying files to their correspondig folder-------------------------
## Getting names of all files in the folder------------------------------------
get_files_path = original_dataset_dir + "/*.npy"
#print(len(get_files_path))
fpath_list = sorted(glob.glob(get_files_path))
for file in fpath_list:
    file = file.split("/")[-1]
    fname = str(file[:-4] + "_a" + ".npy")
    #print(fname)
    src = os.path.join(label_dir, fname)
    dst = os.path.join(data_dir, fname)
    shutil.copyfile(src, dst) 
#rename the masks_____________________________________________________
#get_files_path = data_dir + "/*.*"
#fpath_list = sorted(glob.glob(get_files_path))
#for file in fpath_list:
#    fname = str(file[26:-4]) + "_a" + ".npy"
#    src = os.path.join(data_dir, str(file[26:]) )
#    dst = os.path.join(data_dir, fname)
#    os.rename(src, dst)
#
# Out:
# data_HR/val/images
